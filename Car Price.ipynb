# %% [raw]
# Major Project: Predictive Modeling of Car Prices for Market Entry
# Strategy in the US Auto Industry

# %% [raw]
# Problem Statement
# A Chinese automobile company Geely Auto aspires to enter the US market
# by setting up their manufacturing unit there and producing cars locally to
# give competition to their US and European counterparts. They have
# contracted an automobile consulting company to understand the factors on
# which the pricing of cars depends. Specifically, they want to understand
# the factors affecting the pricing of cars in the American market, since those
# may be very different from the Chinese market. The company wants to
# know:
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large
# data set of different types of cars across the America market.

# %% [raw]
# What We Are Trying to Solve
# We are required to model the price of cars with the available independent
# variables. It will be used by the management to understand how exactly
# the prices vary with the independent variables. They can accordingly
# manipulate the design of the cars, the business strategy etc. to meet
# certain price levels. Further, the model will be a good way for management
# to understand the pricing dynamics of a new market.

# %% [raw]
# We need to import our file, to do this we will use panda library

# %%
import pandas as pd
df = pd.read_csv('CarPrice_Assignment (2).csv')

# %% [raw]
# Now we will check the first five row elements in our dataset.
# To do this we will use the head() function.

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [raw]
# If we want to check the type of data we are working with then we will use the following function.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# To know the shape of the data ( means no. of rows & coloumns)
# We will use the following code.

# %%
df.shape
# Out:
# (205, 26)

# %% [raw]
# In the dataset the car_ID coloumn is of no use therefore we can drop this whole coloumn.
# To drop the car_ID coloumn we will use the following code.

# %%
df = df.drop(['car_ID'], axis = 1)

# %% [raw]
# Now we will check the shape of the dataset to know that the car_ID coloumn is removed or not.
# Therefore we will use the shape function.

# %%
df.shape
# Out:
# (205, 25)

# %% [raw]
# Now we will check the first five row elements in our dataset.
# To do this we will use the head() function.

# %%
df.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %% [raw]
# Now, here we can see that there is no car_ID coloumn. This means that it has been completely deleted from our dataset.

# %% [raw]
# Now if we want to know the data type of the different coloumns
# We will use the following code.

# %%
df.dtypes
# Out:
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [raw]
# Now we need to check that is there any null value in our dataset or it is not present.
# To check for the null values we will use the isna() function.

# %%
df.isna()
# Out:
#      symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0        False    False     False       False       False    False
# 1        False    False     False       False       False    False
# 2        False    False     False       False       False    False
# 3        False    False     False       False       False    False
# 4        False    False     False       False       False    False
# ..         ...      ...       ...         ...         ...      ...
# 200      False    False     False       False       False    False
# 201      False    False     False       False       False    False
# 202      False    False     False       False       False    False
# 203      False    False     False       False       False    False
# 204      False    False     False       False       False    False
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  enginesize  \
# 0         False           False      False      False  ...       False
# ...

# %% [raw]
# Now here we can see that all the rows and columns are not shown.
# Therefore we will use the other method to find for the null values.
# we will be using the following function

# %%
df.isna().sum(axis = 0)
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [raw]
# Now we can see that there is no null value in the dataset.

# %% [raw]
# Now, lets plot the boxplot for our dataset.
# This can be done using the boxplot() function.

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [raw]
# Here we cannot see boxplot for all the variables because there are many columns in our dataset.
# Therefore we will go for the column-wise boxplot for our dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['symboling'])
# Out:
# <Axes: xlabel='symboling'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['CarName'])
# Out:
# <Axes: xlabel='CarName'>

# %% [raw]
# We can see that for columns of object type datatype boxplot is not important.
# Therefore we will only plot boxplot for the integer and float type datatypes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['wheelbase'])
# Out:
# <Axes: xlabel='wheelbase'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['carlength'])
# Out:
# <Axes: xlabel='carlength'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['carwidth'])
# Out:
# <Axes: xlabel='carwidth'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['carheight'])
# Out:
# <Axes: xlabel='carheight'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['curbweight'])
# Out:
# <Axes: xlabel='curbweight'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['boreratio'])
# Out:
# <Axes: xlabel='boreratio'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['stroke'])
# Out:
# <Axes: xlabel='stroke'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['compressionratio'])
# Out:
# <Axes: xlabel='compressionratio'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['horsepower'])
# Out:
# <Axes: xlabel='horsepower'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['peakrpm'])
# Out:
# <Axes: xlabel='peakrpm'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['citympg'])
# Out:
# <Axes: xlabel='citympg'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['highwaympg'])
# Out:
# <Axes: xlabel='highwaympg'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot (x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %% [raw]
# Now from these all boxplot we can find that wheelbase, carwidth, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, & price columns have outliers present in them.
